# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash8292/Dental-Disease-Detection-using-Deep-Learning/blob/main/Dental_diseases_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install labelImg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 31.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 16.2 MB/s eta 0:00:00
# ...
#   Created wheel for labelImg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261520 sha256=10bdb9570a646e81cb7e664249f2e046696d729d8f299cc181b0fb0a4bfe64ea
#   Stored in directory: /root/.cache/pip/wheels/79/90/db/e0700438d3647c0209061d77992c901d3c786a56fec574ac86
# Successfully built labelImg
# ...

# %%
# !pip install labelme
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for labelme: filename=labelme-5.6.1-py3-none-any.whl size=1439255 sha256=4128626af7e918fd86b758a1fdde036033693188679a227a5e7cbb81539159aa
#   Stored in directory: /root/.cache/pip/wheels/4c/d1/73/0265c5803f9958b493ab1cab184a30928f5dd68bf010e733a7
# Successfully built labelme
# ...

# %%
pip install ultralytics torch torchvision opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 885.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZOv92xgfdEJR5GdS7raK")
project = rf.workspace("yolo-v8-training").project("tooth-caries-1tfry")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=dataset.yaml epochs=50 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 115MB/s]
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import os

dataset_path = "/content/Tooth-Caries-1"
if os.path.exists(dataset_path):
    print("✅ Dataset found at:", dataset_path)
else:
    print("❌ Dataset not found! Check your Roboflow download path.")
# Out:
# ✅ Dataset found at: /content/Tooth-Caries-1

# %%
yaml_content = """path: /content/Tooth-Caries-1
train: train/images
val: valid/images
test: test/images

nc: 1
names: ["decay-cavity"]
"""

with open("/content/Tooth-Caries-1/data.yaml", "w") as file:
    file.write(yaml_content)

print("✅ data.yaml updated successfully!")
# Out:
# ✅ data.yaml updated successfully!

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # Load pre-trained YOLOv8 model

# Train YOLOv8
model.train(data="/content/Tooth-Caries-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import os

model_path = "/content/runs/detect/train4/weights/best.pt"
if os.path.exists(model_path):
    print("✅ Model file found:", model_path)
else:
    print("❌ Model file NOT found! Check your training process.")
# Out:
# ✅ Model file found: /content/runs/detect/train4/weights/best.pt

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("/content/runs/detect/train4/weights/best.pt")

# Predict on an image
results = model.predict(source="Dental_Disease.jpg", save=True, imgsz=640)

# Display the predicted image
from IPython.display import display
from PIL import Image

image = Image.open("runs/detect/predict/Dental_Disease.jpg")  # Adjust path if needed
display(image)
# Out:
# image 1/1 /content/Dental_Disease.jpg: 448x640 3 decay-cavitys, 199.6ms
# Speed: 9.1ms preprocess, 199.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=898x588>
